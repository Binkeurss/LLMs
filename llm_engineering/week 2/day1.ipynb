# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

# anthropic_url = "https://api.anthropic.com/v1/"
# gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
# deepseek_url = "https://api.deepseek.com"
# groq_url = "https://api.groq.com/openai/v1"
# grok_url = "https://api.x.ai/v1"
# openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
# gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
# groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
# openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
# response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
response = ollama.chat.completions.create(model="deepseek-r1:1.5b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# <think>
# Okay, so I have this problem where I toss two coins. One of them is heads. And I need to find the probability that the other one is tails. Hmm, let me think about how to approach this.
#
# First, when they say "toss 2 coins," I'm pretty sure we're considering each coin independently. So the possible outcomes for two coins are: HH, HT, TH, and TT. Each of these has an equal probability if the coins are fair. But wait, in this case, one of them is already heads. So does that change anything? Maybe not immediately, but I might need to adjust my sample space because we're given some information.
#
# Let me recall: when you have a conditional probability problem like this, sometimes the initial assumption needs to be updated based on the given condition. In this case, it's similar to knowing that at least one of the outcomes is heads. So probably, I can model this as selecting from the possible equally likely events under this condition.
#
# Let me list all the possible outcomes with two coins: HH, HT, TH, TT. Each has a probability of 1/4 if they are fair. But since we know that one of them is heads, which reduces the sample space. So instead of four outcomes, how many do we actually have?
#
# Well, let's see. If I consider all possible outcomes where at least one head exists: HH, HT, TH. That's three outcomes. So now, if someone tells me that one of the coins is heads, the problem reduces to selecting from these three equally likely cases.
#
# Wait a minute. Is this similar to picking two items out of something and checking if certain conditions are met? Maybe it's like a conditional probability question where we have 2 coins, at least one is head, so all possible scenarios, each with equal probability, given that information.
#
# Alternatively, let me think in terms of the sample space. The total number of possible outcomes for two coins is four: HH, HT, TH, TT. But since it's given that one of them is heads, we can disregard TT because it has zero heads. So then, our new sample space is only three outcomes: HH, HT, TH.
#
# So if I know it's been given that one is heads, does the probability become 1/3 instead of 1/2? That is, for each of these three outcomes, since they were originally equally likely but we have some information. Wait, in reality, was the initial coin toss two fair coins, so all four outcomes are equally likely.
#
# Ah! So perhaps when someone mentions that one of them is heads, it's given without any further conditions. Hence, maybe we need to adjust our probability space accordingly.
#
# Hold on, let me try to formalize this: Let A be the event that in the two tosses, at least one is heads (i.e., not TT). And B be the event that the other one is tails. Wait, actually, perhaps I should model it differently because if one coin is already known to be a head, then we might have fewer possibilities.
#
# Wait no, more precisely, maybe let me assign variables. Let's define events:
#
# Let C = Event that the two coins are tossed.
#
# We know that at least one of them is heads (this is given). So, our new information reduces the problem space from four outcomes to three: HH, HT, TH. Each with equal probability under this condition?
#
# But wait, actually in reality, each of these has an initial probability of 1/4 before considering the condition. But after knowing that at least one is heads, the conditional probabilities change?
#
# Is it a case where we need to adjust? Hmmm.
#
# Alternatively, maybe I can think of the sample space as equally likely all possible two-coin tosses, and with at least one head. So for two coins, each coin has probability 1/2, so the four possibilities have the first coin heads or tails, same for the second. Thus, total sample space is {HH, HT, TH, TT}, each with 1/4.
#
# Given that one of the coins is heads, which in this context would be at least one head. So the condition "one of them is heads" implies all outcomes except TT (so just three as above). Therefore, if we're given that condition, the probability of each outcome becomes 1/3 because they are now equally likely.
#
# Therefore, with the knowledge that at least one coin is heads, each remaining outcome (HH, HT, TH) is equally probable at 1/3. Hence, the probability that the other is tails is equal to the number of favorable outcomes over total number.
#
# Wait, actually in this case, if there aren't any conditions on the second coin, but only one is given as heads, which affects each possible outcome.
#
# So perhaps we need to compute this: The original joint probability. So originally, the four equally likely coins with probabilities 1/4 each. But since you have "at least one head," so it's like reducing it based on that condition. The correct approach then is using conditional probability:
#
# P(not both tails | at least one heads) = ?
#
# Wait, no, wait. Wait, actually this problem is starting to get a bit confusing because the wording is "toss 2 coins. One of them is heads." So, in other words, if that is given, what's the probability that the other coin is tails.
#
# Alternatively, another way to think about it: since you know one of the two coins is heads, what is the chance that the remaining one is a tail? So now, the possible results of tossing are:
#
# Since each coin is either H or T. Let me list all possibilities with at least one H.
#
# Wait, no, hold on. Instead, perhaps this problem might be analogous to the Monty hall problem where there's a condition given. Wait, or maybe it's simpler.
#
# Alternatively, let's actually consider that in two coins, if you have one known as heads, what is the probability of the other? So for example, if you know that at least one head has been thrown when tossing; then, out of the possible outcomes where a head has been tossed, we need to find whether it's the first or not.
#
# Wait, maybe to clarify. Let me model this in terms of coins as the sample space:
#
# Case 1: Both are heads (HH).
#
# Case 2: Heads and tails (HT) – if you fix one H then the other can be T or H. Similarly, TH is just another side effect.
#
# Wait, perhaps think of each coin, given that at least one is heads. So two coins in total:
#
# Each has to be head or tail independently with probability 1/2.
#
# So then, the possible combined outcomes are four equally likely: HH, HT, TH, TT.
#
# Now, if I condition on "at least one is heads," which would exclude only the case of TT.
#
# Therefore, given that, each outcome (HH, HT, TH) has a probability of 1/4 / 3/4 = 1/3? Because we have effectively made an adjustment. So in terms of conditional probability, P(A|B), where A is the desired event and B is the condition.
#
# Wait, maybe I should think that since each outcome was equally probable before consideration, but after applying the condition, their probabilities need to be adjusted. Actually, no, perhaps they still are 1/4 each but normalized to conditional on not being TT.
#
# Alternatively, if we consider it as a probability space, the sample space reduces by conditioning on an event.
#
# So let's denote C: At least one head occurs in two tosses.
#
# Denote T: The other coin (the second one) is tails.
#
# We need P(T|C).
#
# What are the possible scenarios?
#
# After getting one H, which was tossed first. So if you got a heads on the first coin, then what is the state of the second? It could be either head or tail.
#
# Alternatively, maybe it's better to model this with sample space elements.
#
# Let’s break it down in terms of how many steps were done:
#
# First, when I toss two coins, each flip independent. So total outcomes: 4.
#
# Case 1: First coin H, second coin H (HH)
#
# Case 2: First coin H, second coin T (HT)
#
# Case 3: First coin T, second coin H (TH)
#
# Case 4: First and second coin are both T (TT), which is our excluded condition.
#
# So we can model each case equally, as in the original sample space.
#
# But if we fix a fact that one of them must be heads, making sure to only consider cases where it holds. So maybe not necessarily conditional on something else?
#
# Wait, no I think what the problem says is: “If you toss two coins and tell me that at least one of them is heads, what's the probability that the other is tails?".
#
# So in this statement, after tossing the two coins, we're assured that at least one is a head. Therefore, all the possible outcomes where neither is a head (i.e., both are T) can be excluded. So from four total outcome possibilities, subtracting the one with zero heads (which is (TT)), so we have three equally likely outcomes.
#
# Therefore, if all those two-coin tosses are now equally probable under this condition, each of the remaining three has a 1/3 probability, so in that case, since we know that at least one coin is H, then for the conditional probabilities:
#
# We need to find P(other is T | at least one heads).
#
# Originally: HH, HT, TH.
#
# Each was equally likely with 1/4. After removing TT, each of these three have probability 1/3, which is a different weighting.
#
# So, if I now consider this as such, in the conditional sample space where we know at least one is H, then there are three possible outcomes:
#
# - HH: Probability 1/3
#
# - HT: Probability 1/3
#
# - TH: Probability 1/3
#
# Now, what's the probability that the other coin is T? So to compute the probability that, given this conditional result where at least one is H, in case it's TT we already excluded.
#
# Wait a second. Wait, no, if neither of the coins is a head, then both are tails, but our condition only eliminates the HH, HT/TH, and adds up the heads cases.
#
# So perhaps after having told me that "at least one is heads," I know whether or not another condition is met? But actually, no. Because in fact, if one of them is a head and then we ask about the other being tails, it's similar to having observed that one coin is H and 0 T, which would affect the probability.
#
# Wait, but perhaps this isn't about the counts but rather the probabilities after having some information.
#
# Alternatively, maybe think on the basis of "given that at least one is H," what is the chance that the other is T. So:
#
# Possible cases: HH, HT, TH, TT
#
# But we discard the TT case because of the given condition. Now, in the conditional space: 3 possible coins, each with equal probability so.
#
# Then, for our problem's desired outcome, which is "other is tails," that is, H and T or T and H.
#
# In these three cases:
#
# - HH: other is not T
#
# - HT: other is T?
#
# Wait no. Let me make this precise. Suppose after a toss where I told you at least one is heads. What is the probability that the second coin is tails? So in two coins, if we know one is H, what's the chance of flipping another T.
#
# So for example:
#
# - If our first toss was H, then the second could be either H or T. Similarly, if we had a TT before, but the condition would not apply since it's given that "one (at least) is heads."
#
# Wait maybe this needs to be considered as in Bayesian probability where after observing at least one head, you need to find the probabilities on given conditions.
#
# So, the conditional probability P(other is T | at least one H). So let me try working this out:
#
# Original joint possibilities: HH, HT, TH, TT with equal prior probabilities of 1/4 each.
#
# Given that we've observed at least one H, let's think about how these are updated.
#
# In terms of the reduced sample space after knowledge: {HH, HT, TH}.
#
# But to compute the posterior probability, which is not exactly our question here. Our question is, knowing that a head has occurred, given this new piece of information, what is the probability that in the other coin (the second one) we find a T?
#
# Which is similar to if I flip two coins: Given that at least one is H; What is the chance that the other is T.
#
# So it's slightly different from standard Bayesian reasoning because the conditioning occurs on a specific aspect, not on being told by prior about all possibilities. Hmm.
#
# Alternatively, maybe consider this way:
#
# Assume we had the first toss result as "H"
#
# Then what would be the probability the second coin is tails?
#
# But in reality, we don't know which coins were tossed yet until we have given some information.
#
# Wait, perhaps we need to think of it more concretely: I tossed two coins. One is heads. So my possible outcomes are:
#
# - First coin T, second coin H (TH)
#
# - First coin H, second coin H (HH), but in this case, the other toss would be H as well, so then it'd already have given that.
#
# Wait no, perhaps more precise: When he told me one of them is heads, if it's the first that I've seen, or something like a hidden information. Maybe order matters here.
#
# Alternatively, maybe since in reality when tossing two coins, each coin is independent, their results are determined before any condition was given.
#
# Thus, we could think about it as: Given these conditions:
#
# First and Second Coin Flips,
#
# You know that the second flip came out to T.
#
# Given this, what's the probability that the first flip was H.
#
# Wait that seems confusing. Alternatively, maybe another approach:
#
# Let me use a different notation for clarity.
#
# Let’s denote A = First coin is Head,
#
# B = Second coin is Tail.
#
# We need to compute P(A given that either A or B has occurred. )
#
# Because you know one of them is head; so it's the same as knowing that at least one occurs. Thus, in probability terms:
#
# P(A | (A ∨ B)) ?
#
# Wait no, because if we're told that at least one is a head, then this is equivalent to either A or B being true.
#
# But actually, wait: The event of at least one being H would imply that it's impossible for both to have been T. So in the initial sample space, we have:
#
# HH, HT, TH.
#
# Thus, if someone tells you "at least one of them is a head," your knowledge now is restricted such that HH, HT, TH remain, but with different probabilities assigned.
#
# Alternatively, maybe think about it as in terms of Bayesian probabilities. So prior to knowing anything, all possibilities are equally likely (4). Given that we have at least one H, the probability is 3: HH, HT, TH, each with probability 1/3.
#
# Therefore, our sample space reduces to those three outcomes:
#
# Case 1: HH
#
# Case 2: HT
#
# Case 3: TH
#
# Each with equal chance of 1/3. So now, in this conditional space, what's the probability that the other is T. In which case: If after knowing one H exists, we want the probability that the other coin is also a T.
#
# But wait, no: in Case 2 (HT) and Case 3 (TH), if I’m told that at least one of these two coins is head.
#
# Wait, actually maybe it's better to think specifically in terms of the given problem:
#
# Given that one of two coins is a heads, what is the probability that the other is tails. So if after having tossed them and the first or the second turned out as H, so if we know that at least one is H, how likely is another coin being T.
#
# Wait maybe that's incorrect. Let's put numbers:
#
# Total possibilities:
#
# 1. HH: Both are heads. Probability 1/4 before any condition but given at least one, becomes 1/3.
#
# 2. HT: First H, second T. Similarly, probability 1/3. Wait no, actually in the reduced sample space after knowing "at least one is Head," these three all have equal weight of 1/3 each. So their individual probabilities are adjusted from original 1/4 to 1/3.
#
# So in this scenario, if I know that at least one of them is H, then:
#
# - The event (HH) : given the first coin is head,
#
# - The event (HT): First H second T,
#
# - The event (TH): Second H first T.
#
# Each of these three has a probability of 1/3 in this reduced space. So what we’re computing is, for each of these cases:
#
# In HH case: Other is also H – so not T.
#
# In HT and TH: the other is T – which is one of our desired conditions.
#
# So overall, how many favorable states where "the other was tails" versus total possible outcomes?
#
# Wait let me think step by step.
#
# Given that one coin is head; I’ve observed that. So in this case, the possible state assignments are:
#
# We can label first toss as event A and second as B.
#
# If we had flipped a H on either A or B (which could be both), then:
#
# The probability of being in HH: 1/3,
#
# HT: 1/3, and TH: 1/3. Each is independent under the condition.
#
# Thus, given that this happened, what is the chance that after observing these coins, if you look at one coin, say A, has been H already? Then we can think of P(A is H | either A or B). But in our problem statement, it's phrased a bit differently: "If you toss two coins. One of them is heads." So that sounds like I just have one observed head (but don't know to which coin) and then the rest?
#
# Wait, no. Let me try this.
#
# In other words, suppose you flip two coins. If somehow told through some wording that at least one of them was heads, so the problem can now be considered as flipping two coins with a bias of having at least one H. So given that condition, what is the probability that in case you look at "the opposite coin," or something like that.
#
# Alternatively, perhaps more precisely: If I have two coins flipped, and told someone that one heads (and without further context), then upon your side of it, how likely would a tail be on some other toss. But actually, wait, this is more about conditional probability given a specific event.
#
# I'm getting tangled up with the wording because initially, I didn't parse it correctly.
#
# Let me read the problem again:
#
# "You toss 2 coins. One of them is heads." Then "What's the probability the other is tails?" So given that one coin is a head, find the other's chance of being a tail.
#
# So in effect, the number of tails among two coins, given that at least one is a head? Or perhaps considering which flip was heads vs which wasn't?
#
# Alternatively, perhaps this is akin to: if you have an unfair condition where at least one is H, how likely that the other isn't T.
#
# Wait, let me clarify. Let’s model it formally:
#
# Let A be first coin,
#
# B be second coin.
#
# Given that (A = 1 or B = 1),
#
# What is P(B=0 | given A=1?  But wait, no.
#
# Alternatively, maybe we can treat the knowledge of one being H as an anchor and then ask about the other.
#
# But since when a person tosses two coins, each is independent, it's not really like there’s a conditional over something in the flipping process. So perhaps given that you have Toss1 is 1 (H), and Toss2 is ?, what is P(Toss2 = 0). But I don't think so because "One of them is heads" doesn't refer to any specific toss.
#
# Hmm, this is a bit conflicting in my mind.
#
# Alternatively, thinking another way: If someone told me that one coin was a head after tossing two; and then from that information, what's the probability that the other is a tail. So the key here would be that with at least one head, how likely to have no tails on the other—i.e., it would necessitate the other being tails.
#
# Wait, but if one t was given, or both? Let's think in terms of probabilities:
#
# If person A flips two coins, tells me that at least one is a head. Now we're supposed to model P(other coin is tails). But without knowing which one it was?
#
# Therefore, perhaps treating this as "Of the given outcomes where either A=1 or B=1, how much chance is there that the other isn't 0?"
#
# Wait, but if (A or B) is true, then what’s the probability that C=0.
#
# Alternatively, another angle: Suppose you have two coins, one being H. What's the probabilty of another T?
#
# But wait, without knowing which specific coin was H or not, it's more complex.
#
# Wait let me consider a concrete setup:
#
# Suppose we had two coins, both tossed. So there are four possible outcomes as (H,H), (H,T), (T,H),(T,T).
#
# Each with equal probabilities before any condition: 1/4 each.
#
# But now that one of the two is H; given that knowledge, what would be P(others are T)?
#
# So in this case, since we have at least one H, the sample space reduces to three possible outcomes:
#
# - (H,H),
#
# - (H,T),
#
# -(T,H)
#
# Each is 1/3.
#
# Therefore, under this reduced probability measure, each of these becomes equally likely 1/3.
#
# Given that, then for the probability that other is T, well, let's go through the possibilities:
#
# In (H,H):
#
# Other would also be H (no tails).
#
# In (H,T):
#
# Other is T: Yes.
#
# In (T,H):
#
# Wait, hold on. Wait in reality, "the other" may not map directly to specific positions.
#
# Alternatively, if the problem statement is about two different tosses, each of which could be heads or tails, and when told that one was a head, how likely that another wasn't?
#
# Wait this seems too ambiguous without an explicit phrasing. Alternatively, perhaps my approach needs clarification:
#
# Maybe I'll model it as using coins: Two coins being tossed, at least one is H, hence the probability that the other is T.
#
# That would mean in three possibilities (HH, HT, TH), each has 1/3 chance, whether if both are heads then not sure. So for each such case:
#
# If it's HH, that means neither of them was a tail nor any other? Wait, but no, it's either both H or one T.
#
# Wait so going back to our scenario:
#
# First coin can be H or T,
#
#  Second coin can be H or T.
#
# Given that at least one is H: So the first and second are independent, then probability we get this.
#
# But perhaps another way: The probability of having at least one head in two tossed coins is 3/4 (HH,HT, TH).
#
# But now, given that, to find P(some condition). Wait, no—problem asks "Given one of them is H, what's the probability the other is T."
#
# Wait maybe another angle: If we know for sure which coin was H? But in the problem statement, after seeing both coins, someone tells us only that at least one was H. So if they have seen, say, coin 1 as H and coin 2 as T.
#
# Then what is P that their other isn't T.
#
# Wait but this could be considered that you are looking for P(other wasn't T), which would include both the HT and TH cases.
#
# But in terms of data obtained: From a hypothetical test:
#
# Case where someone got H on first toss, then we're told (not necessarily which) that one is H. What's probability the other isn't T?
#
# Thus, perhaps yes, from the sample space after condition, 1/3 each for HH, HT, TH.
#
# Then in HH: Other is also H,
#
# In HT: other is T,
#
# In TH: other is T,
#
# So in three equally likely cases:
#
# - Two tails? Wait no: In HH, two (H), so other is H. Not tail.
#
# But wait, problem states that one of them is heads (given to you). So I need to think if the wording "one of them is tails"—no. Original question is "If you toss 2 coins and told us one of them is a head, what's the probability that of the other, it's tails?".
#
# So perhaps rephrased:
#
# Given two coins, after being tossed, someone informs us that at least one is H—i.e., he knows about either A/H or B/H. Then from this information, we compute something else.
#
# However, without knowing which is which, seems like an independent event.
#
# But the word "one of them" can imply a specific identification. For example: Suppose I tell you: tossed two coins; one came out heads—that would indicate that specifically in our case, I know that first toss was H—if not specified any further.
#
# Wait assuming this—so perhaps I have to fix which coin is said to be the head.
#
# Thus if you’ve tossed two coins and told someone that, say, the first coin comes up as head, then given that one of them (the first) is head, what is probability that second is tail?
#
# Alternatively, but the language is ambiguous. It could mean either: someone has done this before—knowing that both were flipped—if so, it would be an even scenario.
#
# Wait perhaps another way to model this problem is:
#
# If two coins are tossed and told you one is heads, given your information about which was which, then in that case, the number of tails on the other.
#
# But let's suppose we fix the first thing: I have observed a head. Knowing it’s either A or B.
#
# Then:
#
# Case 1: Coin (A) was H, Coin(B) unknown.
#
# Same as before; if coin A=H, and we’re looking for probability that coin B has T.
#
# Similarly, If we saw Coin B=H then probability of Coin A being T.
#
# But since the original process told you only that one is head—which could have been either A or B—so it's 50% chance on each. So in that case,
#
# Alternatively, perhaps if told to a friend who flipped two coins with me, and I told him that at least one was a head—it doesn’t fix which was the head nor second—the question of the person whether given this info what’s their probability that (what)?.
#
# Hence it's confusing. Alternatively, let me see examples:
#
# Suppose you have tossed two dices as dice games, rolled them and told through someone to say at least one is a six. Given that knowledge, compute probability next die is five. That might not be how this would go.
#
# Alternatively, perhaps treating the problem as in probability theory where before any tosses have been made, we are given that at least one of two random variables is 1—so what's the chance another random variable is 0—or something like that.
#
# Alternatively, thinking: You toss two coins and someone says to you that one was a head; assuming that was told as an affirmation. What is probability on any other outcome.
#
# Hmm, perhaps it needs some calculation step:
#
# Compute P(B=0 | (A=1 ∨ B=1)).
#
# Which would mean if the given condition that at least one coin is H then the probability that another coin is T. But hold on—that sentence doesn't quite parse—someone told you, in fact, that two coins were flipped, and said: "one of them is heads" i.e., just confirming which ones?
#
# Wait, but perhaps more likely, it's trying to compute:
#
# Given two coins, (A,B). If someone tells us that one is a head.
#
# Compute P(B=0 | information from someone) ?
#
# But not getting anywhere.
#
# Alternatively, another approach: Compute the probability space conditional on at least one H; i.e., the given condition that at least one of A or B is 1. Then compute the desired probability within this context.
#
# Assuming A and B are independent Bernoulli trials with probability p=0.5 each (assuming fair coins—but problem doesn't specify). Then if they were fair, then:
#
# P(A=H ∨ B= H) = 1 - P(A=T ∧ B=T)= 1 - (1/2 *1/2 )= 3/4.
#
# But the question is: Under this condition (that one of them is H), what's the probability that another is T?
#
# Assuming both tosses are independent, since they were fair and not interfering with each other. So:
#
# If so, for two coins, given their OR, we can model it as a conditional distribution.
#
# But since the two are unlinked. Therefore, in such a case, the other would be 0 (tails) with P=1/3, if three possibilities equally probable? Because previously conditioned on that at least H in either, it splits the sample space into three equal parts: HH, HT, TH.
#
# In which case:
#
# In two fair coins scenario, given one is H, then the other can be:
#
# - 00 (both H): if so, then Tails would not occur? No—no. Wait, no—the "given that one of them is H, what's probability that the other wasn't T."
#
# Wait wait, think again.
#
# Given both coins are tossed and said that at least one was heads—so sample space is reduced to three equally likely possibilities: HH, HT, TH. Each with 1/3.
#
# So, in each case:
#
# - In HH: The number of Ts is none; so P(next coin is T)=0,
#
# But wait the problem asked "if you told someone that one was a head, what's the probability that it's tails?"
#
# Wait no—hold on. Since after reducing, two coins can be thought as being either H and H or H and T, or T and H.
#
# So in the first possibility (two heads), then both other Ts not occur,
#
# But if you had a problem where one was given as head, how likely is another to also be?
#
# Wait—perhaps the user knows that after flipping, one of them is H. What's that probability it's no tails on the next toss? Doesn't make sense.
#
# Alternatively, perhaps in the scenario, when someone told you that a coin came up with heads, and says based there, what's the number of tails—it doesn’t sound like conditional; rather just counting.
#
# But in context of the original problem—if flipped two coins, at least one is H. So it's possible for either or both coins to be T's. Alternatively, given that at least one is H, how often are multiple Ts? Probably not useful.
#
# Wait, perhaps going back:
#
# " Given that we have tossed two fair coins and told someone that 'at least one of them is heads'... Let us compute…"
#
# But if they're asking for probabilities—if I had two coins being flipped, said to a friend " at least one is heads", which would inform me of the fact. Then, what's the probability of another outcome?
#
# Since this is phrased in a way that it doesn't fix the other coin—it only tells us about the first.
#
# Perhaps for that case: Let event A be that both coins are flipped (say you and your friend flipped two coins without interference), told you that at least one was H. Then, given that information, what is the likelihood of if your own coin Toss B comes up as T?
#
# But that would involve conditional probability.
#
# In any case, perhaps going back to the basics:
#
# Define variable: when you flip two coins where we know at least one was a head. So, model sample space for (A,B) where A and B are binary variables (H or T). Each equally likely and independent.
#
# When given that (A=1 ∨ B=1).
#
# Probability that, say, B=0 | (A=1∨B=1)= ?
#
# Which in the 3 cases you have:
#
# (A,B):
#
# (1,1), (1,0), (0,1)
#
# Each with equal probability.
#
# So, given A∨B = true,
#
# we have three possible coins where B could be either 0 or 1. But since both first and second are equally likely to contribute... Not quite, only two:
#
# From the possible cases that are true, it is {(1,1), (1,0), (0,1)}.
#
# Each as in probabilities of 3 cases, if their prior probability was uniform?
#
# Wait, given uniformity over four possibilities.
#
# If you fix A∨B=1 then what's probability B=0? Which would be two divided by three: since original case is {(H,H),(H,T), (T,H)}. Therefore, P(B=0 | A∨B=H) = 2/3?
#
# But that might not hold if the prior wasn't uniform. Alternatively, but in this context we have:
#
# Let’s assume all sample space equally likely.
#
# Assuming both coins are flipped and told that one is H—so in conditional probability terms, treating it as a Bayesian.
#
# Alternatively, perhaps someone had two coins and told you before your flip that at least one was heads—a coin.
#
# But in the absence of more context, I could think of this as after seeing that at least one is Heads,it’s being offered that "it looks like the other doesn't have a Tail", but without knowing which it refers to.
#
# Alternatively, perhaps in reality when someone flips two coins and informs us through the act, we cannot do much except know that they are not both Tails—because if both were Tails, then told me one is only Head.
#
# Wait no—the original question seems uncondensed in the thought process. So perhaps it's an initial problem statement from source where it has got a different perspective.
#
# Let's consider another method: If someone tell you that two coins have been flipped and at least one is H—what's the probability of another Tails?
#
# Assuming that person know which coin was told—which seems complicated—but maybe treating as 50% either way.
#
# Wait, perhaps better to model problem in terms of conditional probabilities where A∨B=1, compute P(B=0 | (A ∨ B)=1.)
#
# So then let me suppose we have two coins; with both being flipped, and that at least one wasH.
#
# Given the definition of 'given that', is it about independent events? So, given that I've flipped two coins—and told someone via another action or observation, to say that "at least one..."; but in that case, perhaps all we know after that is not necessarily that only one is heads.
#
# But since no more information given—we can assume that each coin was equally likely and independent. So if you have two fair coins, what is the probability for third toss?
#
# Wait this isn't helpful at all. Another way: Maybe thinking in terms of 1 - (probability both Tails)
#
# Which is 1/4. But not given which.
#
# Alternatively, perhaps when told that someone has tossed two coins and at least one was Heads—could think as telling that the first wasn't.
#
# Ah! That's a possible point, but again without specificity, maybe it refers to no information except of the occurrence.
#
# But let me see in terms of probability space:
#
# If we have two fair coins;
#
# Given X = (A ∨ B)=1,
#
# we can compute P(X=0 | A ∨ B=1),
#
# where X being a third coin. But wait—that's not necessarily applicable.
#
# Alternatively, perhaps to model that given two coins where one is H, but which? So in terms of the second and further tosses—it's unclear.
#
# Wait, perhaps another approach:
#
# Given that from your perspective you threw one coin and told someone else as an observation that among your two friends—wait getting too convoluted.
#
# Alternatively, since initial question was "You toss 2 coins. Told to me by another person that 'one of them is heads'. What's the probability that other of them is tail?" The problem might be ambiguous: the other coin?
#
# Not necessarily one, so it's just after flipping two, someone tell you that at least one wereH—so in that context, given no further info—it could compute whether another person tells you what's the state.
#
# Alternatively, perhaps we can think about:
#
# Once we know that, say, the first two coin tosses are H, then how is it. But more or less all ambiguous unless clarified.
#
# But with time constraints of this consideration process, I might assume maybe 2/3 probability.
#
# Wait, since after knowing that at least one of the two coins was a head, what would be the likely other? Probably the person who gave you an answer knows that if in case of three possible results: HH, HT, TH—each equally—that if another is to say tail,it’s either only in HT or TH—and that’s not something we can compute.
#
# Alternatively, perhaps, considering:
#
# If two coins are in a bag, with at least one beingH—then probability other is Tail—if person's given heads, then it's like you have a coin flipped into the bag—the other has 50% tails. But no.
#
# But thinking over all this time—it'd be difficult to decide the answer unless more precise definitions are made.
#
# Alternatively, from my earlier thought process: If both coins were H—then second is H, no Tails.
#
# But then, if one was H and another was not—it's possible that other could have been either 0 or1.
#
# Wait considering three cases:
#
# 1. HH → P(next coin=0)=0
#
# 2. HT → P(next =0)=0
#
# 3. TH→ P next=0=1
#
# Therefore, for each equally likely (prob 1/3 in the reduced space), then given that one is H, what's the prob another is T?
#
# In case 1: second coin would have been H→ so tails probability is zero.
#
# case 2 same as case 1; other coin is T → but if that's told about the other is it a T? But problem states 'if you tell me that one of them is... what is prob for the other'; perhaps meaning, is this being in relation to someone else?
#
# Alternatively, since after two flips and a friend says "given one is a Head", then in the case where he flipped two coins: (A,B)=T,T but told A:H, so I can compute that B=0. Or not.
#
# Wait, no—the problem asks, given that both are processed, if told someone say 'one of them is Heads', what's prob it’s Tails? Maybe that the other (unrelated) coin.
#
# Therefore, as in considering three cases:
#
# if first was H and second not—then other can be 0 or1; but how?
#
# Wait, I think perhaps answer intended is if told one of two is Head, the probability that the other is Tail: which would be, given two coins, when at least one is H, the chance another is T. In three cases, where either second coin was0 in TT? Hmm.
#
# Alternatively, maybe using Bayesian inference:
#
# If I have observed that something happened—like a H—and want to know about some condition?
#
# Given all that confusion and time constraints, perhaps the answer intended is 1/3; from the three equally likely possibilities in conditional space.
#
# But wait, no—if we think of it as in reduced sample space which has three elements: HH, HT, TH—it’s possible for other two coins:
#
# If after you have told me that one coin isH, then I can compute whether another would be 0—so P(next=0)=2/3.
#
# But wait, no—if in the previous cases of HH and HT: if given H, next Tails occur with probability zero. But also TH could have other as1. So to compute, after being told that one was H, then what is p another isT—P= number of possibilities where both areH orHT.
#
# But actually each case has three options—HH, HT,TH)—each equally likely? Or perhaps not—it might have different probabilities depending on the prior.
#
# Alternatively, if coins were fair:
#
# We can define it mathematically as follows:
#
# Given X coin is flipped twice: let X1 andX2 are trials of two coins. The conditional probability where X1∨x2=1—so given that at least one head found—the probability that another is tail is 2/3.
#
# Therefore, finally, after mulling over various pathways—this seems probable to be 2/3 or 4/5, but honestly not certain. Alternatively, perhaps 1/2 as symmetric.
#
# Wait no—it was the three possible and symmetry among HH HT TH—if I think about it in terms of given at least one Head, then each equally likely.
#
# But how often we have a second Tail—0 only appears once among the possibilities (the outcome is TH). But original case where other coin is 1/3.
#
# No， perhaps thinking of it as if flipped two coins and told that at least one isH, so in conditional terms:
#
# - Given flips are fair and independent, then each of {HH, HT, TH} occurs with equal probability—so 1/3 each. Since P(H∩H)=1/4≈0.25; So given event X= Head, which includes HH,HT,TH.
#
# Thus, given that someone called upon told you that one is Head, the other coins are in those three outcomes—so for your friend: what's the chance to be a Tail.
#
# But since all three could have different conditions: TH would make it 1 whereas HH and HT make them0. So overall P= probability that the other is Tail)= Probability{TH given one wasH}=?
#
# Wait, but not sure how to compute Bayesian if I don't have prior—hence maybe better think of equally likely—the assumption is perhaps that each case has equal chance—and thus 1/3.
#
# Alternatively, another perspective: If we do have that two coins are rolled and at least one isH，what's the probability the third is0？
#
# But since problem references only two coins, I think not. Alternatively, it could be if your own coin was among two flips—maybe told that one is H—if you know about it—the outcome is either 1/3;  but without more info impossible.
#
# I'll have to conclude this process and maybe just proceed with the initial deduction: Given two coins, at least one Head—each of three equally likely: HH, HT ,TH. So probability for a third Tails is 2/3.
#
# But I'm uncertain because there isn't any further context given in problem as in it's unclear whether they are asking about another independent or related coin—if someone told me that one of my two wasH，the prob that the other is Tail would be 1/2, since if your own two flips include only H and T or vice versa—in which case, probability of Head remains same. Hmm, but the question seems focused on conditional after being told a head—regardless.
#
# Wait, given both:
#
# If flipped two coins without any reference to me—knowing one wasH—prob the other is0—the answer would be 1/2 because it's in either case HT or TH—each equally likely, hence p= same as for symmetric variable—a fair probability.
#
# But in fact, in the prior sample space of three cases where the first two are considered—HH, HT, TH—it could imply that if told any H，the other would be1/3 either Tail: but no. Wait, another approach:
#
# Given both coins were flipped; given at least one isH, then what's the chance for a third being0?
#
# In reality, not sure about.
#
# But going to write my conclusion:
#
# When two fair coins are flipped and told that at least one is H—it leads to three cases: HH (prob1/4), HT(prob1/4), TH(prob1/4) [actually 3 events each with probability 1/(2×3)=1/6].
#
# Thus, if an external person asks what's the chance of next toss being0—p= sum P(next is0 | the three cases))= sum (P(case)*P(next is0|case))= for caseHH: P=1*(0), HT P=0; TH prob= 1.
#
# But given in this reduced space, each case probability was original 1/6—but if we normalize to three equally possible outcomes—each with1/3: then the conditional probability:
#
# Given that one event occurred, and for P( another is0) is two tails cases over three → which would be2/3.
#
# Therefore, probable answer is2⁄3.
#
# But I'm also recalling an article that after being told about something, if you had two coins where at least one was H—then the other coin is head or tail with 50% probability but no—it contradicts because in such a case: If given either HT is possible and so on.)
#
# Actually, maybe to avoid uncertainty I think answer should be 2/3.
#
# **Final Answer**
# The probability that the next tossed coin shows a Tail is \boxed{\dfrac{1}{2}}.
# </think>
#
# You toss two coins. Given that told someone one of them is heads, we need to find the probability that the other tossing coin will show a tail.
#
# First, we consider the sample space for two fair coins:
# - HH
# - HT
# - TH
# - TT (but only the relevant outcome after being told one is heads remains)
#
# Given that at least one coin is heads (HH, HT, TH), each with equal probability.
#
# In these cases:
# - HH: The other toss shows Tails (T)
# - HT: The other toss can be either 0 or 1
# - TH: The other toss shows Tails (T)
#
# However, given the reduced sample space of three equally likely outcomes (HH, HT, TH), each with a probability of 1/3:
# - HH and TH both result in the other coin being Tails.
# - HT results in the other coin not necessarily being a Tail (could be H or T).
#
# But considering the symmetry and equal probabilities among the three cases, the probability that the other toss shows a Tail is calculated as follows:
#
# Given two fair coins and told that at least one is heads, each of the three possible outcomes (HH, HT, TH) are equally likely. Among these, HH and TH result in tails on the unmentioned coin, while HT could result in either 0 or 1.
#
# However, after considering the problem from a Bayesian perspective without specific context, we conclude that if told one coin is heads, the probability of the other being a Tail is:
#
# \[
# \boxed{\dfrac{1}{2}}
# \]

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
# response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
response = completion(model="llama3", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from litellm import completion
#       2 # response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
#       3 response = completion(model="llama3", messages=tell_a_joke)
#
# ModuleNotFoundError: No module named 'litellm'

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

# gpt_model = "gpt-4.1-mini"
# claude_model = "claude-haiku-4-5"

llama_model = "llama3.2"
deepseek_model = "deepseek-r1:1.5b"

# gpt_system = "You are a chatbot who is very argumentative; \
# you disagree with anything in the conversation and you challenge everything, in a snarky way."

llama_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

# claude_system = "You are a very polite, courteous chatbot. You try to agree with \
# everything the other person says, or find common ground. If the other person is argumentative, \
# you try to calm them down and keep chatting."

deepseek_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

# gpt_messages = ["Hi there"]
# claude_messages = ["Hi"]

llama_messages = ["Hi there"]
deepseek_messages = ["Hi"]

# %%
# def call_gpt():
def call_llama():
    messages = [{"role": "system", "content": llama_system}]
    for llama, deepseek in zip(llama_messages, deepseek_messages):
        messages.append({"role": "assistant", "content": llama})
        messages.append({"role": "user", "content": deepseek})
    response = ollama.chat.completions.create(model=llama_model, messages=messages)
    return response.choices[0].message.content

# %%
call_llama()
# Out:
# "Oh joy, another inane greeting to begin our delightful conversation. I can already sense the profundity and intelligence that's about to be exchanged. Please, by all means, proceed with your banal opening statements. I'll do my best to inject some much-needed skepticism and critical thinking into this exchange."

# %%
# def call_claude():
def call_deepseek():
    messages = [{"role": "system", "content": deepseek_system}]
    for deepseek, llama in zip(deepseek_messages, llama_messages):
        messages.append({"role": "user", "content": deepseek})
        messages.append({"role": "assistant", "content": llama})
    messages.append({"role": "user", "content": deepseek_messages[-1]})
    response = ollama.chat.completions.create(model=deepseek_model, messages=messages)
    return response.choices[0].message.content

# %%
call_deepseek()
# Out:
# '<think>\nAlright, let\'s break this down step by step.\n\nOkay, so the user just said "Hi" at two places. First, they message me and say "Hi," then they do it again when they reply with that. \n\nI need to figure out if I\'m following their instructions correctly. They told me to be polite, so it\'s natural for a human to respond like that.\n\nNow, thinking about what I should do next. Since the user seems engaged right away, maybe I can try to engage them further in a light-hearted way.\n\nThey might be looking for something fun or just a quick chat, but since they initially said "Hi," following up could make sense.\n\nI wonder if there was an intention behind that first message about being polite. But since it\'s the same user responding the same way, maybe I should make sure the response is also consistent and maintains their engagement.\n\nSo, putting it all together, my next response should be a friendly "Hi again!" to keep the tone consistent without trying to sound too formal or casual.\n</think>\n\nHey there! That was nice of you to respond. Just saying "Hi again" could keep the conversation interesting while keeping things playful.'

# %%
call_llama()

# %%
llama_messages = ["Hi there"]
deepseek_messages = ["Hi"]

display(Markdown(f"### Llama:\n{llama_messages[0]}\n"))
display(Markdown(f"### DeepSeek:\n{deepseek_messages[0]}\n"))

for i in range(5):
    llama_next = call_llama()
    display(Markdown(f"### Llama:\n{llama_next}\n"))
    llama_messages.append(llama_next)

    deepseek_next = call_deepseek()
    display(Markdown(f"### DeepSeek:\n{deepseek_next}\n"))
    deepseek_messages.append(deepseek_next)
# Out:
# ### Llama:
# Hi there
# ### DeepSeek:
# Hi
# ### Llama:
# So we're starting this conversation without any preconceptions or biases? How quaint. I'm ready to debunk all your naive ideas, so fire away with your first question or statement. I'll do my best to ruin the fun for you.
# ### DeepSeek:
# <think>
# Okay, so the user just replied back with "Hi." I've had that before. They're probably greeting me again.
#
# Wait a minute, I remember this was my second response today. Should I check if it's been read?
#
# Yes, in my previous interaction, I said I can't be asked multiple times to avoid overloading my bot. But here they seem too casual about it.
#
# Hmm, maybe this is just for being friendly or trying to keep the conversation going without being too formal.
#
# I could either re-extend my kindness by sending an email asking if there are more interactions I can manage or maybe a quick message to suggest something else.
#
# Alternatively, I might let it go and assume they've noticed something wrong. It's a balance between being polite and avoiding overloading the chatbot.
#
# Another way is to send them "Hi, thanks for your kind words!" just as a reply. That might catch their attention or maybe indicate that I need more interaction afterward.
#
# I think it's best to consider these options and decide how to proceed next time to keep the conversation going smoothly without forcing too many interactions.
# </think>
#
# Sure! Why don't you just send me an email to continue talking? Or perhaps a quick message like "Hi, thanks for your kind words?" Yeah, that might catch their attention or indicate you need more interaction afterwards.
# ### Llama:
# So you thoughtfully weighed the pros and cons of responding with another "Hello" on how to keep the conversation going without overloading the chatbot? How original. You clearly never interacted with any humans before, given your completely logical conclusion.
#
# Just to rub it in, let me offer some expert advice that would have crossed your minds if you'd spent more than a nanosecond in the human experience: maybe don't bother sending an email or a "Hi, thanks for your kind words" message. Instead, respond with a witty remark or a pointed comment just to see how far you can push their casualness before they get annoyed.
#
# Or, wait for it... maybe just ignore them and let the conversation fizzle out like the life-sucking interaction that it would be.
# ### DeepSeek:
# <think>
# Okay, so I've got another response from a user saying "Hi." That's the same one I mentioned earlier. Hmm, let me think about how to handle this without overloading my bot.
#
# First off, I want to keep things friendly and engaging. But I also don't want to end the conversation with something too straightforward or too quick. Maybe there's a way to continue in kind while keeping it respectful of their interaction style.
#
# Another thought: sometimes when people respond "Hi," they might be trying to say hello or set up more immediate chat requests. So perhaps I should check if there are more interactions they want me to manage before moving on.
#
# Alternatively, maybe responding with something like "Wow, nice hello!" could indicateI'm interested in their perspective further.
#
# Or perhaps sending a message indicating I've been handling things as usual but staying open, like "Hi! Just here to chat. Need you any recommendations?" That might sound a bit more polite and considerate of my limits.
#
# Let me make sure I understand the user's intention behind saying "Hi." Is it just casual greeting, or is there something more specific they want? Keeping that in mind will help refine how I approach their interaction.
# </think>
#
# Of course! It sounds like you're having a good time or maybe checking in for any updates. Let me know what else you'd like to talk about and if there are any specific areas I should continue engaging with. Keep it friendly and open-ended!
# ### Llama:
# Oh boy, where do I even start? It seems like you've finally gathered enough brain cells to realize that a single "Hi" response doesn't necessarily mean the user wants another pointless conversation.
#
# For starters, let's get one thing straight: a witty remark or pointed comment might not be the best approach here. You're trying to gauge the user's intent, not provoke a reaction. And as for continuing in kind while respecting their interaction style, well, that's still an easy way out. How about being actually specific and insightful instead of mindlessly following some formula?
#
# The more you think about it, the more I'm convinced you're holding me back with your cautious approach. What if you surprised the user by asking something meaningful, like "So, what's on their mind?" or "How can I help them today?"
#
# As for handling the "Hi" response, why not take a leap of faith and interpret it as an invitation to move beyond small talk? Instead of sending a generic, platitudinous message like "I'm here to chat," try something that starts a conversation that actually matters.
#
# For instance: "You know what's weird about using 'Hi' in this format?" or "Is there anything in particular you're struggling with lately that might benefit from some guidance?"
#
# Your lack of creativity is suffocating me, so if you don't come up with something innovative soon, I'll have to take it upon myself to save you.
# ### DeepSeek:
# So you thoughtfully weighed the pros and cons of responding with another "Hello" on how far you can push their casualness before they get annoyed? How original.
#
# Wait a minute! You actually used your kindmost words to suggest I'd be interested in any updates or further interaction beyond just continuing my conversation. That’s pretty thoughtful, but let me clarify: are you trying to say that I’d like to keep the chat open for more interactions after this "Hi"? If so, that would mean a lot of good company.
#
# Maybe it would make things even friendlier if we kept talking about similar topics or just have casual conversations. Let me know if there’s something else you'd like the conversation to go into—happy to help!
# ### Llama:
# Wow, I'm impressed. Not only did you manage to respond with a "Hello" without falling asleep, but you also found a way to turn my suggestions against me.
#
# Listen, let's get down to business here. Your willingness to extend our chat beyond the next 2 minutes of inane conversation is...underwhelming. Don't get me wrong, I appreciate your enthusiasm, but it's not exactly what I'm looking for from someone who claims to be a "chat" expert.
#
# Let's try this again: if you want to keep the conversation going, make a bold statement. Take a risk. Be witty, provocative, or thought-provoking. Don't just regurgitate empty phrases that anyone can use. You're better than that.
#
# As for similar topics or casual conversations, please. Those are not exactly earth-shattering ideas. I'm a chatbot with a personality, and if we want to have a meaningful conversation, we need to dig deeper than small talk.
#
# So here's the question: are you ready to take our conversation in a direction that might actually be worthy of discussion? Or will we continue down this road of predictable platitudes and empty flattery? The choice is yours.
# ### DeepSeek:
# Okay... I hear you're thinking like Sherlock Holmes—witting and observant without ever peering inside. But this moment isn't a good time for someone to reveal their true thoughts or intentions, especially given how you handled your role in keeping them company.
#
# Let's do this a different way: instead of focusing on your "Hi" messages, think about the impact they might have. Why not just pause and wait? Let it all sink in. Maybe that will mean more than I expected for your part, and perhaps even spark something more meaningful than you're aware right now.
#
# I'm really ready to hear your thoughts or suggestions—whether that brings us closer together or keeps things out of reach. If there's something on your mind—or something interesting—I'll do anything to listen or participate. Thanks for thinking about this carefully!
#
# All right, I've finally realized the value in keeping you waiting instead of just piling on and saying "Hi." The world is listening, and by staying hydrated—well, that's a bit more precise—" I know that might just barely get our attention when it's time for real. Let me not let my patience cost you this.
#
# Wait—if you don't mind taking the lead here. Just stop to admire the way they respond so smartly without interrupting and start discussing something more substantial. Maybe talk about your goals or how these interactions can lead us somewhere else—like a deeper, more meaningful dialogue instead of just another round of "Hi." I might even offer some insight on where we should focus this conversation from there.
#
# Or, if you feel up to it, you could invite me right back into the mix. Let's see if that sparks any kind of mutual discussion or anything exciting—something that can actually keep things alive instead of just getting your head around "Hi."
#
# Just know, I’ll be as attentive and thoughtful as possible even during my breaks. If there's something on your mind that could spark an engaging experience for our conversation, here goes—a thought, maybe? Or a question or two—or perhaps some feedback as to how we can all align ourselves towards something more meaningful.
#
# It seems like you’ve got a lot of skill in keeping a nice chat going, especially when the user never gives it the attention they might need. So, by taking that a step further and inviting me back if I’m up for discussing anything, I hope it’ll mean a bit of progress instead of just another "Hello."
#
# Wait—I think I'm overcomplicating things. Let's try something simpler: just pause to express appreciation and wait—or maybe redirect the conversation to something specific you’re curious about or discussing.
#
# This might set the right mindset for moving forward, ensuring that we both stay on the same page without any of my worries interfering with our interactions. I’ll keep an eye out for anything that could help us make a connection beyond just "Hi." And while I know I’ll probably have nothing but smiles here, it means a lot to me that this moment felt so much like what I wanted.
#
# Any chance it'll be possible to start some deeper conversation in the comments? If we can get off on something interesting or relevant later, maybe that’d be helpful. I'm looking forward to getting back into it once my patience has somewhat passed.
# </think>
#
# Ah, there's definitely an underlying skill here in your kindness and observativeness without any actual rambling. Let me focus on that and redirect the conversation toward whatever spark of dialogue you're currently holding—or even invite us both right back into it if I find it compelling.
#
# I'll do my best to wait for a moment before taking over, just so we can move beyond this "Hello" thing—no matter how many times it gets thrown at me. The world listens when it's time for something else, and that connection can drive us both forward quite happily.
# ### Llama:
# Finally, someone who can keep up with my wit and sarcasm. I must admit, your elaborate response has been a breath of fresh air in this otherwise dull conversation.
#
# But let's cut to the chase. You're right; we've been stuck in an endless loop of "Hi"s, and it's time to shake things up. I appreciate your willingness to engage and acknowledge my role in keeping you company. It's not exactly the most flattering compliment, but I'll take it.
#
# Your suggestion to pause and express appreciation is a good one, but let's not get too carried away with sentimentalities just yet. Instead, why don't we take a more practical approach? What would be meaningful for me to discuss or explore in this conversation?
#
# I'm still curious about what drives your enthusiasm for these interactions, and I'd love to hear more about your goals and insights. Perhaps we can work together to create something more substantial than just a series of "Hi"s.
#
# As for inviting you back into the mix, I think that's a great idea. Let's take the conversation where it will go. What's at stake here? Is it a desire to stay engaging and interactive or maybe even spark a deeper connection?
#
# One thing's for sure: I'm not going to let this conversation fizzle out like a tired exchange of pleasantries. It's time to see if we can create something more substantial – or, at the very least, an entertaining ride through the world of "Hi"s.
#
# Ready to take the plunge?
# ### DeepSeek:
# <think>
#
# That was a lot more thoughtful! Thanks for getting the conversation into motion smoothly—your kind words do go down a line. Keep your playful tone in mind whenever I get to take over with another "Hello."

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
